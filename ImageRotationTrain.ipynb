# %% [markdown]
# <a href="https://colab.research.google.com/github/hbasafa/ImageRotation/blob/master/ImageRotationTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/d4nst/RotNet.git
! cd RotNet
# Out:
# Cloning into 'RotNet'...
# remote: Enumerating objects: 154, done.
# remote: Total 154 (delta 0), reused 0 (delta 0), pack-reused 154
# Receiving objects: 100% (154/154), 10.35 MiB | 35.80 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=396e14b27f8c8d96b790ca676d059caa234fdf7fd995b77762d680a983b59e7a
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
! python RotNet/train/train_street_view.py
# Out:
# Using TensorFlow backend.
# 2020-05-31 10:13:20.401313: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
#
# Extracting part1.zip
# ...
#
# Extracting part2.zip
# ...
#
# Extracting part3.zip
# ...
#
# Extracting part4.zip
# ...
#
# Extracting part5.zip
# ...
#
# Extracting part6.zip
# ...
#
# Extracting part7.zip
# ...
#
# Extracting part8.zip
# ...
#
# Extracting part9.zip
# ...
#
# Extracting part10.zip
# 37234 train samples
# 4138 test samples
# 2020-05-31 10:51:16.301537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-31 10:51:16.362400: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-05-31 10:51:16.369010: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (94353003e6bc): /proc/driver/nvidia/version does not exist
# ...
